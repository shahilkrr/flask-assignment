# %%
#Question 1

# %%
#Flask is a web framework that allows developers to build lightweight web applications quickly and easily.
#Advantages - 1) simple and flexibility 2) personalization 3) fast and efficient 4) less loding time 5) Scalibility

# %%
#Question 2

# %%
'''from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")'''
# Out:
# 'from flask import Flask\n\napp = Flask(__name__)\n\n@app.route("/")\ndef hello_world():\n    return "<h1>Hello, World!!</h1>"\n\nif __name__=="__main__":\n    app.run(host="0.0.0.0")'

# %% [markdown]
# ![Screenshot (385).png](attachment:d23fbe14-841c-410b-912b-d594a3e70e4b.png)

# %%
#Question 3

# %%
#App routing is the technique used to map the specific URL with the associated function intended to perform some task.
#This allows us to create a structured and organized web application with distinct functionalities for different routes.

# %%
#Question 4

# %%
'''from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def welcome_message():
    return "Welcome to ABC Corporation"

@app.route("/a")
def details():
    return "Company Name: ABC Corporation <br> Location: India <br> Contact Detail: 999-999-9999"
            
if __name__=="__main__":
    app.run(host="0.0.0.0")'''
# Out:
# 'from flask import Flask\n\napp = Flask(__name__)\n\n@app.route("/welcome")\ndef welcome_message():\n    return "Welcome to ABC Corporation"\n\n@app.route("/a")\ndef details():\n    return "Company Name: ABC Corporation <br> Location: India <br> Contact Detail: 999-999-9999"\n            \nif __name__=="__main__":\n    app.run(host="0.0.0.0")'

# %% [markdown]
# ![Screenshot (388).png](attachment:2307914a-a834-4039-b13b-24caab37c919.png)

# %% [markdown]
# ![Screenshot (386).png](attachment:1a4ad783-c3cf-4813-b0b6-0fd2d7a78c88.png)

# %%
#Question 5

# %%
#url_for() function is used to build a URL.
